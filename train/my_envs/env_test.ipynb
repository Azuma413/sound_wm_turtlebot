# %%
from gym_env import MyEnv3, MyEnv2, MySimulator3 # カスタム環境の読み込み
import numpy as np
import matplotlib.pyplot as plt

env = MyEnv3() # 環境のインスタンス化

# %%
obs = env.reset() # 環境のリセット
# 画像の表示
print(obs.shape)
print(obs.dtype)
plt.imshow(obs)
# Out:
# [[0 0]
#  [5 0]
#  [5 3]
#  [7 3]
#  [7 5]
#  [4 5]
#  [4 8]
#  [0 8]]
# image shape: (257, 275, 3)
# x: (256,) y: (275,)
# (128, 128, 3)
# float32

# %%
# エピソードの実行
done = False
#action = env.action_space.sample() # ランダムな行動の選択
action = np.array([1.,-0.3])
# print('action:', action) # 行動の表示
# for i in range(100):
obs, reward, done, info = env.step(action) # 行動の実行
img = env.render()
print(img.shape)
# print(img.dtype)
plt.imshow(img) # 画像の表示
plt.show()
print('reward:', reward) # 報酬の表示
# print('info:', info) # infoの表示
print('done:', done) # エピソードの終了の表示
# Out:
# x: (256,) y: (275,)
# (660, 604, 3)
# reward: -0.8823519173773198
# done: False

# %%
plt.imshow(obs) # 画像の表示
