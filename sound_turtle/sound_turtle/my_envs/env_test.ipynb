# %%
import numpy as np
import matplotlib.pyplot as plt
from my_env import MyEnv, WrapDrQ

env1 = MyEnv()
env2 = WrapDrQ(env1)
# env1.reset()
# corner = env1.my_sim.corners
# sound = env1.my_sim.sound_locations_2d[0]
# plt.scatter(corner[:,0],corner[:,1],c='pink')
# plt.scatter(sound[0],sound[1],c='yellow')
# plt.gca().invert_yaxis()
# plt.axis('equal')
# plt.show()
# Out:
# [[ 2.24 -0.01]]
# [[ 6.39842809  3.92432858]
#  [ 5.68600676  4.52212106]
#  [ 5.04321915  3.75607662]
#  [ 4.22355159  4.44385936]
#  [ 3.78002814  3.91528869]
#  [ 3.11969783  4.46937161]
#  [-1.29303911 -0.78952349]
#  [ 2.000952   -3.55351021]
#  [ 4.82921748 -0.18291466]
#  [ 3.72764557  0.74141392]]

# %%
obs = env1.reset() # 環境のリセット
# 画像の表示
plt.imshow(obs)
# Out:
# [[ 2.24 -0.01]]
# [[ 6.39842809  3.92432858]
#  [ 5.68600676  4.52212106]
#  [ 5.04321915  3.75607662]
#  [ 4.22355159  4.44385936]
#  [ 3.78002814  3.91528869]
#  [ 3.11969783  4.46937161]
#  [-1.29303911 -0.78952349]
#  [ 2.000952   -3.55351021]
#  [ 4.82921748 -0.18291466]
#  [ 3.72764557  0.74141392]]

# %%
pixel = [20, 40]
coord = env1.my_sim.pixel2coord(pixel)
print('pixel:', pixel)
print('coord:', coord)
print('pixel:', env1.my_sim.coord2pixel(coord))
# Out:
# pixel: [20, 40]
# coord: [5.64 4.44]
# pixel: [20 40]

# %%
# エピソードの実行
done = False
#action = env.action_space.sample() # ランダムな行動の選択
action = np.array([0., -0.])
obs, reward, done, info = env1.step(action) # 行動の実行
img = env1.render()
print(img.shape)
print(img.dtype)
plt.imshow(img) # 画像の表示
print('obs shape: ', obs.shape)
print('obs type: ', obs.dtype)
print('reward:', reward) # 報酬の表示
print('done:', done) # エピソードの終了の表示
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 5
#       3 #action = env.action_space.sample() # ランダムな行動の選択
#       4 action = np.array([0., -0.])
# ----> 5 obs, reward, done, info = env1.step(action) # 行動の実行
#       6 img = env1.render()
#       7 print(img.shape)
#
# File ~/Document/VScode/sound_turtlebot/sound_turtle/sound_turtle/my_envs/my_env.py:260, in MyEnv.step(self, action)
#     258 self.trajectory.append(self.my_sim.coord2pixel(self.my_sim.center).tolist())
#     259 # シミュレーションの実行
# --> 260 self.my_sim.simulate()
#     261 # 観測の取得
#     262 obs = self.my_sim.image/255.0
#
# File ~/Document/VScode/sound_turtlebot/sound_turtle/sound_turtle/my_envs/my_env.py:155, in MySimulator.simulate(self)
#     153     aroom.add_source(self.sound_locations[i], signal=self.audio) # 運が悪いと音源が壁の中に生成されることがある
#     154 # シミュレーションの実行
# --> 155 aroom.simulate()
#     156 X = pra.transform.stft.analysis(aroom.mic_array.signals.T, self.nfft, self.nfft // 2)
#     157 X = X.transpose([2, 1, 0])
#
# File ~/anaconda3/envs/jax_env/lib/python3.10/site-packages/pyroomacoustics/room.py:2418, in Room.simulate(self, snr, reference_mic, callback_mix, callback_mix_kwargs, return_premix, recompute_rir)
#    2416 # compute RIR if necessary
#    2417 if self.rir is None or len(self.rir) == 0 or recompute_rir:
# -> 2418     self.compute_rir()
#    2420 # number of mics and sources
#    2421 M = self.mic_array.M
#
# File ~/anaconda3/envs/jax_env/lib/python3.10/site-packages/pyroomacoustics/room.py:2290, in Room.compute_rir(self)
#    2287 # Use the Cython extension for the fractional delays
#    2288 from .build_rir import fast_rir_builder
# -> 2290 vis = self.visibility[s][m, :].astype(np.int32)
#    2291 # we add the delay due to the factional delay filter to
#    2292 # the arrival times to avoid problems when propagation
#    2293 # is shorter than the delay to to the filter
#    2294 # hence: time + fdl2
#    2295 time_adjust = time + fdl2 / self.fs
#
# IndexError: list index out of range

# %%
plt.imshow(obs) # 画像の表示
